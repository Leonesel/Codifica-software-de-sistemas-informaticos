# %%
#-------------------------------------------------------------------------#
#Crear una tuple con 3 elementos: 10, "Hola" y 3.14
print("tuple de 3 elementos:")
tuplencio = tuple([10,"Hola",3.14])
print(tuplencio)
print()
#-------------------------------------------------------------------------#
#La tupla(1,2,3,4,5), accede y escribe el tercer elemento
tupla = (1,2,3,4,5)
print("El tercer elemento de la tupla es:",tupla[2])
print()
#-------------------------------------------------------------------------#
#Concatena las tuplas y almacena el resultado en una tupla Nueva
print("Dos tuplas en una")
tupla1 = ("vanessa","es","lesbiana")
tupla2 = ("leonel","es","gay")
tupla_final = tupla1+tupla2

#-------------------------------------------------------------------------#
#Desempaqueta la tupla en tres variables y escribe sus valores
print("desmenusar la tupla en 3:")
tupla = ('a','b','c')
var1= tupla[0]
var2= tupla[1]
var3= tupla[2]
print("1:",var1)
print("2:",var2)
print("3:",var3)
print()
#-------------------------------------------------------------------------#
#verifica si el elemento 7 existe en la tupla (1,3,5,7,9)
print("El elemento 7:")
tuplan = (1,3,5,7,9)

existe = tuplan[3]
print(existe)
print()
#-------------------------------------------------------------------------#
#crea una tupla (0,1,2,3,4,5) y escribe los elementos del indice 2 a 4 con slice
print("Indicar posición del 2 al 4:")
sopes = (0,1,2,3,4,5)
resultado = sopes[2:5]
print("Los numeros de la posición dos a la 4 son:",resultado)
print()
#-----------------------------------------------------------------------#
#encuentra la longitude de una tupla (10,20,30,40,50)
print("Encuentra la longitud de la tupla:")
huaraches =  (10,20,30,40,50)
length = len(huaraches)
print("La longitud es:",length)
print()
#-------------------------------------------------------------------------#
#crea una tupla y repitela 3 veces
print("3 veces:")
tuploss = tuple(["Lesbiana","Gay","Hetero"])
print(tuploss)
print(tuploss)
print(tuploss)
print()
#-------------------------------------------------------------------------#
#convierte la lista[1,2,3] a tupla
print("De lista a tupla:")
gogo = [1,2,3]
tuple(gogo)
print(gogo)
print()
#-------------------------------------------------------------------------#
#Encuentra los valores minimo y maximo de la tupla(5,12,3,8,15)
print("El mínimo y el máximo:")
tuplu = (5,12,3,8,15)
valor_minimo = tuplu[2]
valor_maximo = tuplu[4]
print('Minimo: ',valor_minimo,' Maximo: ', valor_maximo)
# Out:
# tuple de 3 elementos:
# (10, 'Hola', 3.14)
#
# El tercer elemento de la tupla es: 3
#
# desmenusar la tupla en 3:
# 1: a
# 2: b
# 3: c
#
# El elemento 7:
# 7
#
# Indicar posición del 2 al 4:
# Los numeros de la posición dos a la 4 son: (2, 3, 4)
#
# Encuentra la longitud de la tupla:
# La longitud es: 5
#
# 3 veces:
# ('Lesbiana', 'Gay', 'Hetero')
# ('Lesbiana', 'Gay', 'Hetero')
# ('Lesbiana', 'Gay', 'Hetero')
#
# De lista a tupla:
# [1, 2, 3]
#
# El mínimo y el máximo:
# Minimo:  3  Maximo:  15

# %%
print(tupla_final)
